# %% [markdown]
# <a href="https://colab.research.google.com/github/teacher-e/lab/blob/main/dic_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![dic_ex.png](data:image/png;base64,...)

# %%
dic_num = {'유재석':[55,47,36],'노홍철':[63, 52, 45],'박명수':[46,50,35]}
sales1 = dic_num['유재석']
sales2 = dic_num['노홍철']
sales3 = dic_num['박명수']
print('유재석 평균 : ', sum(sales1)/len(sales1))
print('노홍철 평균 : ', sum(sales2)/len(sales2))
# Out:
# 유재석 평균 :  46.0
# 노홍철 평균 :  53.333333333333336

# %%
sales_list = list(dic_num.values( ))
A = sales_list[0][0] + sales_list[1][0] + sales_list[2][0]
B = sales_list[0][1] + sales_list[1][1] + sales_list[2][1]
C = sales_list[0][2] + sales_list[1][2] + sales_list[2][2]
print('A제품 평균 : ', A/3)
# Out:
# A제품 평균 :  54.666666666666664
